# %%
import os
os.chdir("/Users/678094/Desktop/Goodreads")

print(os.getcwd())
# Out:
# C:\Users\678094\Desktop\Goodreads

# %%
import requests
import bs4
import re
import numpy as np
import pandas as pd

# %%
page1 = 'https://www.goodreads.com/genres/list?page=1'
page2 = 'https://www.goodreads.com/genres/list?page=2'
page3 = 'https://www.goodreads.com/genres/list?page=3'
page4 = 'https://www.goodreads.com/genres/list?page=4'
page5 = 'https://www.goodreads.com/genres/list?page=5'

# %%
req1, req2, req3, req4, req5 = [requests.get(page)
                                for page in [page1, page2, page3, page4, page5]]

# %%
type(req5)
# Out:
# requests.models.Response

# %%
soup1, soup2, soup3, soup4, soup5 = [bs4.BeautifulSoup(page.text, "lxml")
                                    for page in [req1, req2, req3, req4, req5] ]

# %%
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage ">
# <head>
# <title>
# Genre shelves
# </title>
# <script type="text/javascript">
#         if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#         </script>
# <script src="https://s.gr-assets.com/assets/webfontloader-d12a76562d1fabc96ea2ca165a5f46ae.js"></script>
# <script>
# //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
# </script>
# <link href="https://s.gr-assets.com/assets/goodreads-39672494918316a7049446de501420b6.css" media="all" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" media="all" href="https://s.gr-assets.com/assets/goodreads_split2-a7db8aadb346495f0348e4cb0448ffc3.css" />
# <![endif]-->
# <!--[if lt IE 9]>
#     <link rel="stylesheet" media="screen" href="https://s.gr-assets.com/assets/ie-243e73b5c2539766a7d02b37fdf277f8.css" />
#   <![endif]-->
# <!--[if lt IE 8]>
#     <link rel="stylesheet" media="screen" href="https://s.gr-assets.com/assets/common_images_ie-5b0cc205c33756d8e7e84ce5b8be28e3.css" />
#   <![endif]-->
# <!--[if gte IE 8]><!-->
# <link href="https://s.gr-assets.com/assets/common_images-67dd60a681af04727cf7d18f5c5ba498.css" media="screen" rel="stylesheet"/>
# <!--<![endif]-->
# <script src="https://s.gr-assets.com/assets/desktop/libraries-1c2883cf9caed935dcb88219fd720a9c.js"></script>
# <script src="https://s.gr-assets.com/assets/application-fcec05911cca1750e2279360a958abe6.js"></script>
# <script>
#   //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//www.googletagservices.com/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.f7c56945977a26e29bf48365d10c54f6");
#     googletag.pubads().setTargeting("grsession", "osid.f7c56945977a26e29bf48365d10c54f6");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3
#     });
#   //]]>
# </script>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="bfbZfHtHWsP1Ie2N0dEZ0m/I2lE5WPLjr1l+JJbqx4UjeWX+QlgAc0f2CNwnzZzlVMqbrODGGt5he5RUtp1kGQ==" name="csrf-token"/>
# <meta content="NZ34VFZ8MZ34SEPAPR2Q" name="request-id"/>
# <script src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-0faeb43a7d.js"></script>
# <script src="https://s.gr-assets.com/assets/react_client_side/site_header-9554b696f4.js"></script>
# <script src="https://s.gr-assets.com/assets/react_ujs-4ccbf2988911e470c05b12f779088c68.js"></script>
# <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
# <script>
# //<![CDATA[
#
#   var GoodreadsAnalytics = GoodreadsAnalytics || {};
#   var _gaq = _gaq || [];
#
#   GoodreadsAnalytics.push = function () {
#     _gaq.push.apply(_gaq, arguments);
#   }
#
#   GoodreadsAnalytics.push(['_setAccount', 'UA-968618-1']);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     1,                        // Slot 1
#     'User Status',            // Custom variable name
#     'signed_out',  // Custom variable value: signed_out, signed_in,
#                               //   signed_in_facebook_connected, or
#                               //   goodreads_member_previously_signed_in
#     2                         // Visit-level scope, which means slot 1 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     2,                        // Slot 2
#     'Device Type',            // Custom variable name
#     'desktop',         // Custom variable value: desktop, mobile, or
#                               //   tablet
#     2                         // Visit-level scope, which means slot 2 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_trackPageview']);
#
#   (function () {
#     var ga = document.createElement('script');
#     ga.type = 'text/javascript';
#     ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(ga, s);
#   })();
#
# //]]>
# </script>
# <meta content="Genres on Goodreads. Browse books by 10th-century, 11th-century, 12th-century, 13th-century, 14th-century, 15th-century, 16th-century, 17th-century, 1864..." name="description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@goodreads" name="twitter:site"/>
# <meta content="Genre shelves" name="twitter:title"/>
# <meta content="Genres on Goodreads. Browse books by 10th-century, 11th-century, 12th-century, 13th-century, 14th-century, 15th-century, 16th-century, 17th-century, 1864..." name="twitter:description"/>
# <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
# <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification"/>
# <meta content="app-id=355833469" name="apple-itunes-app"/>
# </head>
# <body class="">
# <div class="content">
# <script>
#   //<![CDATA[
#     // Load Facebook JS SDK
#     $grfb.initialize({
#       appId: "2415071772",
#       grSession: false,
#       serverFBUser: "null",
#       suppressAutoLogin: "false"
#     });
#   //]]>
# </script>
# <div class="siteHeader">
# <script>
# //<![CDATA[
#   ReactStores.NotificationsStore.updateWith({});
#   ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#   ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#   ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
# //]]>
# </script><div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list","browseUrl":"/book","recommendationsUrl":"/recommendations","choiceAwardsUrl":"/choiceawards","genresIndexUrl":"/genres","giveawayUrl":"/giveaway","homeUrl":"/","listUrl":"/list","blogUrl":"/blog/index","editorsPicksUrl":"/voice","newsUrl":"/news","communityUrl":"/group","groupsUrl":"/group","quotesUrl":"/quotes","featuredAskAuthorUrl":"/ask_the_author","searchPath":"/search","discussionsUrl":"/topic","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","logoActionUrl":"https://www.goodreads.com?int=gca_doodle","readingNotesUrl":"/notes?ref=nd","topFullImage":{"topFullImageUrl":"/choiceawards?int=gca_eb","topFullImageAlt":"2018 Goodreads Choice Awards","xs":{"1x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_1x-a419bebd5c60b3b09698deeeaf8a9e7c.png","2x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_2x-7dcc0cf31df691b5d5e6533947add5e9.png"},"md":{"1x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_md_1x-7c91484b0d517c2b9e6ce357ee985a22.png","2x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_md_2x-e29241108fe30ecd47a225166517df92.png"}},"newReleasesUrl":"/book/popular_by_date/2018/11","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":["logo_doodle","newsfeed_impression_tracking","nav_bar_discussions_pane","site_header_top_full_image","news_page"],"defaultLogoAltText":"Goodreads Home","logoAltText":"Choice Awards 2018","mobviousDeviceType":"desktop"}'><header data-react-checksum="603075447" data-reactid=".od5m0lv4zk"><div class="siteHeader__topFullImageContainer" data-reactid=".od5m0lv4zk.0"><a class="siteHeader__topFullImageLink" data-reactid=".od5m0lv4zk.0.0" href="/choiceawards?int=gca_eb"><picture data-reactid=".od5m0lv4zk.0.0.0"><source data-reactid=".od5m0lv4zk.0.0.0.0" media="(min-width: 768px)" srcset="https://s.gr-assets.com/assets/site_header/editorial_top_full_md_1x-7c91484b0d517c2b9e6ce357ee985a22.png 1x, https://s.gr-assets.com/assets/site_header/editorial_top_full_md_2x-e29241108fe30ecd47a225166517df92.png 2x"/><img alt="2018 Goodreads Choice Awards" class="siteHeader__topFullImage" data-reactid=".od5m0lv4zk.0.0.0.1" src="https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_1x-a419bebd5c60b3b09698deeeaf8a9e7c.png" srcset="https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_2x-7dcc0cf31df691b5d5e6533947add5e9.png 2x"/></picture></a></div><div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".od5m0lv4zk.1"><div class="siteHeader__contents" data-reactid=".od5m0lv4zk.1.0"><div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".od5m0lv4zk.1.0.0"><button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".od5m0lv4zk.1.0.0.0" type="button"></button></div><div class="siteHeader__homeIconContainer" data-reactid=".od5m0lv4zk.1.0.1"><a aria-label="Goodreads Home" class="siteHeader__homeIcon" data-reactid=".od5m0lv4zk.1.0.1.0" href="/" title="Goodreads Home"></a></div><a aria-label="Choice Awards 2018" class="siteHeader__logo siteHeader__logo--doodle" data-reactid=".od5m0lv4zk.1.0.2" href="https://www.goodreads.com?int=gca_doodle" title="Choice Awards 2018"></a><nav class="siteHeader__primaryNavInline" data-reactid=".od5m0lv4zk.1.0.3"><ul class="siteHeader__menuList" data-reactid=".od5m0lv4zk.1.0.3.0" role="menu"><li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".od5m0lv4zk.1.0.3.0.0"><a class="siteHeader__topLevelLink" data-reactid=".od5m0lv4zk.1.0.3.0.0.0" href="/">Home</a></li><li class="siteHeader__topLevelItem" data-reactid=".od5m0lv4zk.1.0.3.0.1"><a class="siteHeader__topLevelLink" data-reactid=".od5m0lv4zk.1.0.3.0.1.0" href="/review/list">My Books</a></li><li class="siteHeader__topLevelItem" data-reactid=".od5m0lv4zk.1.0.3.0.2">< ...
# </div>
# <div class="siteHeaderBottomSpacer"></div>
# <script>
#   //<![CDATA[
#     ReactRailsUJS.mountComponents();
#   //]]>
# </script>
# <div class="mainContentContainer ">
# <div class="mainContent ">
# <div class="mainContentFloat ">
# <div id="flashContainer">
# </div>
# <h1>
# <a href="/genres">Genres</a> &gt;
#   Shelves
# </h1>
# <div class="leftContainer">
# <form accept-charset="UTF-8" action="/genres/search" class="exploreSearchForm box greyBox searchBox searchBox--large" method="get" name="shelfSearchForm"><input name="utf8" type="hidden" value="✓"/>
# <input class="searchBox--large__input" id="shelf" name="shelf" placeholder="Find a genre by name" style="width: 508px" type="text"/>
# <input class="gr-button u-marginLeftTiny" type="submit" value="Find Genre"/>
# </form>
# <div class="greyText" style="float: right; margin-right: 20px">
# <form accept-charset="UTF-8" action="/genres/list" id="filterForm" method="get" name="filterForm"><input name="utf8" type="hidden" value="✓"/>
# <span class="greyText smallText">show:</span>
# <select class="smallText" id="filter" name="filter" onchange="document.filterForm.submit();">
# <option selected='"selected"' value="none">All</option>
# <option value="top-level">Top Level Only</option>
# </select>
# </form> </div>
# <br class="clear"/>
# <div class="left" style="width:200px">
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/10th-century">10th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             3,211 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/11th-century">11th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4,476 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/12th-century">12th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             7,467 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/13th-century">13th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,386 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/14th-century">14th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             11,488 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/15th-century">15th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             14,050 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/16th-century">16th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             38,638 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/17th-century">17th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             45,504 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/1864-shenandoah-campaign">1864-shenandoah-campaign</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             35 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/18th-century">18th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             78,928 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/1917">1917</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,113 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/19th-century">19th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             302,254 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/1st-grade">1st-grade</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             44,644 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/20th-century">20th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             604,252 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/21st-century">21st-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             376,374 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/2nd-grade">2nd-grade</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             46,674 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/40k">40k</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             11,495 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/abandoned">abandoned</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,117,630 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/abuse">abuse</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             296,787 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/academia">academia</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             111,735 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/academic">academic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             267,539 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/academics">academics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             40,649 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/accounting">accounting</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4,058 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/accra">accra</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             493 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/action">action</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             609,473 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/activism">activism</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             38,204 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adaptations">adaptations</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             51,194 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/addis-ababa">addis-ababa</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             56 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/addition">addition</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,541 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adolescence">adolescence</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             91,929 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adoption">adoption</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             47,455 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adult">adult</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,080,485 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adult-colouring-books">adult-colouring-books</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             243 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adult-fiction">adult-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,040,718 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adventure">adventure</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,432,493 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adventurers">adventurers</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             5,771 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aeroplanes">aeroplanes</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             644 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/africa">africa</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             190,270 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-american">african-american</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             112,777 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-american-literature">african-american-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             16,822 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-american-romance">african-american-romance</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             11,096 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-literature">african-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             20,953 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/agender">agender</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             182 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/agriculture">agriculture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             15,533 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aircraft">aircraft</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,325 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/airliners">airliners</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             18 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/airships">airships</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,991 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/albanian-literature">albanian-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,570 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alchemy">alchemy</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             19,772 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alcohol">alcohol</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             16,288 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alexandria">alexandria</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             7,843 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algebra">algebra</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,977 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algeria">algeria</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,226 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algiers">algiers</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             915 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algorithms">algorithms</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             3,800 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aliens">aliens</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             172,700 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alternate-history">alternate-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             128,213 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alternate-universe">alternate-universe</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             65,056 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alternative-medicine">alternative-medicine</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             5,447 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amateur-sleuth">amateur-sleuth</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             17,875 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amazon">amazon</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             650,519 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ambulance-service">ambulance-service</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ambulances">ambulances</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             460 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american">american</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             589,152 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-civil-war">american-civil-war</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             25,689 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-classics">american-classics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             66,313 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-fiction">american-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             121,135 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-history">american-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             227,744 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-novels">american-novels</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             33,413 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-revolution">american-revolution</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             22,275 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-revolutionary-war">american-revolutionary-war</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,128 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/americana">americana</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             139,262 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amish">amish</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             50,282 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amish-fiction">amish-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             12,713 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amish-historical-romance-fiction">amish-historical-romance-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             848 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ancient">ancient</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             71,560 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ancient-history">ancient-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             88,755 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/androgyne">androgyne</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             952 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/angels">angels</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             188,882 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anglo-saxon">anglo-saxon</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             10,049 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/angola">angola</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,366 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/animal-fiction">animal-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             25,329 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/animals">animals</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             521,406 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anime">anime</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             46,485 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anthologies">anthologies</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             192,862 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anthropology">anthropology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             157,446 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anthropomorphic">anthropomorphic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             22,229 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anti-racist">anti-racist</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,339 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/antietam-campaign">antietam-campaign</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             63 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/antiquities">antiquities</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             5,865 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/antisemitism">antisemitism</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             5,060 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/apocalyptic">apocalyptic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             116,528 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/apple">apple</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             10,576 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/applied-mathematics">applied-mathematics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             278 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/appomattox-campaign">appomattox-campaign</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             50 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/archaeology">archaeology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             45,023 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/architecture">architecture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             90,134 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/arithmetic">arithmetic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             711 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/army-of-northern-virginia">army-of-northern-virginia</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             119 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/army-of-tennessee">army-of-tennessee</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             123 books
#           </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="left" style="width:200px">
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/army-of-the-potomac">army-of-the-potomac</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             92 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art">art</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             658,889 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-and-photography">art-and-photography</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             10,186 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-books-monographs">art-books-monographs</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             462 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-design">art-design</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             23,037 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-history">art-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             59,919 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/arthurian">arthurian</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             28,737 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/artificial-intelligence">artificial-intelligence</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             16,083 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/asexual">asexual</a>
# </div>
# ...
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,259,516 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/comics-manga">comics-manga</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             94,147 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/coming-of-age">coming-of-age</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             409,575 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/comix">comix</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             64,541 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/communication">communication</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             48,233 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/comoros">comoros</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             526 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/complementary-medicine">complementary-medicine</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,192 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/computation">computation</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,853 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/computer-reference">computer-reference</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,206 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/computer-science">computer-science</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             62,253 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/computers">computers</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             49,675 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/conservation">conservation</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             9,696 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/consumer-economics">consumer-economics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             443 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/contemporary">contemporary</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             3,462,194 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/contemporary-romance">contemporary-romance</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,284,432 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/contemporary-romance-clean">contemporary-romance-clean</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cookbooks">cookbooks</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             427,490 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cooking">cooking</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             222,213 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/coptic-language">coptic-language</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             442 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/coptology">coptology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             90 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/copts">copts</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             524 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/counselling">counselling</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             8,491 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/counter-culture">counter-culture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             8,986 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/counting">counting</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             15,844 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/couture">couture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             547 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cozy-mystery">cozy-mystery</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             245,919 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/crafts">crafts</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             64,587 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/crime">crime</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,191,982 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/criticism">criticism</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             145,949 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/crochet">crochet</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             13,270 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cross-dressing">cross-dressing</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             8,452 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cthulhu-mythos">cthulhu-mythos</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,417 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cuisine">cuisine</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             7,199 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/culinary">culinary</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             23,597 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cult-classics">cult-classics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             32,341 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cults">cults</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             17,285 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cultural">cultural</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             276,510 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cultural-heritage">cultural-heritage</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,580 books
#           </div>
# <div class="clear"></div>
# </div>
# </div>
# <br class="clear"/>
# <div><span class="previous_page disabled">« previous</span> <em class="current">1</em> <a href="/genres/list?page=2" rel="next">2</a> <a href="/genres/list?page=3">3</a> <a href="/genres/list?page=4">4</a> <a href="/genres/list?page=5">5</a> <a class="next_page" href="/genres/list?page=2" rel="next">next »</a></div>
# <br class="clear"/>
# <div class="moreLink">
# <a class="actionLink" href="/shelf">See all shelves...</a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# <div class="footerContainer">
# <div class="footer">
# <div class="copyright">
# ©
# 2018
# Goodreads Inc
# </div>
# <div class="adminLinksContainer">
# <ul class="adminLinks">
# <li>
# <a class="first" href="/about/us" rel="nofollow">about us</a>
# </li>
# <li>
# <a href="/advertisers" rel="nofollow">advertise</a>
# </li>
# <li>
# <a href="/author/program" rel="nofollow">author program</a>
# </li>
# <li>
# <a href="/jobs" rel="nofollow">jobs</a>
# </li>
# <li>
# <a href="/api" rel="nofollow">api</a>
# </li>
# <li>
# <a href="/news" rel="nofollow">our blog</a>
# </li>
# <li>
# <a href="/news?content_type=author_blogs" rel="nofollow">authors &amp; advertisers blog</a>
# </li>
# <li>
# <a href="/about/terms" rel="nofollow">terms</a>
# </li>
# <li>
# <a href="/about/privacy" rel="nofollow">privacy</a>
# </li>
# <li>
# <a class="last" href="/help" rel="nofollow">help</a>
# </li>
# <li class="mobileToggleLink">
# <span class="label">switch to:</span>
# <a href="/toggle_mobile?switch_to=mobile" rel="nofollow">mobile version</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'><noscript data-react-checksum="-1187835555" data-reactid=".1itt8v7xp1c"></noscript></div>
# <div id="overlay" onclick="Lightbox.hideBox()" style="display:none"></div>
# <div id="box" style="display:none">
# <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window"></div>
# <div id="boxContents"></div>
# <div id="boxContentsLeftovers" style="display:none"></div>
# <div class="clear"></div>
# </div>
# <div id="fbSigninNotification" style="display:none;">
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>
# <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
# </div>
# <div id="fb-root"></div>
# <script type="text/javascript">
# //<![CDATA[
#   $grfb.initialize({
#     appId: "2415071772",
#     grSession: false,
#     serverFBUser: null,
#     suppressAutoLogin: false
#   });
# //]]>
# </script>
# <script>
#   //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY', uid: ''};
#   //]]>
# </script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
# </noscript>
# <script>
#   //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
# </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0"/>
# </noscript>
# </body>
# </html>

# %%
genreList = []
for soup in [soup1, soup2, soup3, soup4, soup5]:
    for a in soup.find_all('a', href = re.compile("/genres/")): 
        if a.text: 
            genreList.append(a['href'].split("/", 2)[2])

# %%
genreList[0:10]
# Out:
# ['art',
#  'biography',
#  'business',
#  'children-s',
#  'christian',
#  'classics',
#  'comics',
#  'cookbooks',
#  'ebooks',
#  'fantasy']

# %%
len(genreList)
# Out:
# 1548

# %%
genres = pd.DataFrame(genreList).drop_duplicates(0)

# %%
genres.columns = ['tag_name']

# %%
genres
# Out:
#                             tag_name
# 0                                art
# 1                          biography
# 2                           business
# 3                         children-s
# 4                          christian
# 5                           classics
# 6                             comics
# 7                          cookbooks
# 8                             ebooks
# 9                            fantasy
# 10                           fiction
# 11                    graphic-novels
# 12                historical-fiction
# 13                           history
# 14                            horror
# 15                            memoir
# 16                             music
# 17                           mystery
# 18                       non-fiction
# 19                            poetry
# 20                        psychology
# 21                           romance
# 22                           science
# 23                   science-fiction
# 24                         self-help
# 25                            sports
# 26                          thriller
# 27                            travel
# 28                       young-adult
# 58                      10th-century
# ...                              ...
# 1448        women-and-gender-studies
# 1513                          womens
# 1514                  womens-fiction
# 1515                   womens-rights
# 1516                  womens-studies
# 1517                    wonder-woman
# 1518                        woodwork
# 1519                           words
# 1520                   world-history
# 1521               world-of-darkness
# 1522               world-of-warcraft
# 1523                     world-war-i
# 1524                    world-war-ii
# 1525                         writing
# 1526            wwii-related-fiction
# 1527                           x-men
# 1528                            yaoi
# 1530        young-adult-contemporary
# 1531             young-adult-fantasy
# 1532  young-adult-historical-fiction
# 1533          young-adult-paranormal
# 1534             young-adult-romance
# 1535     young-adult-science-fiction
# 1536                   young-readers
# 1537                            yuri
# 1538                          zambia
# 1539                             zen
# 1540                        zimbabwe
# 1541                         zombies
# 1542              %E6%BC%AB%E7%94%BB
#
# [1237 rows x 1 columns]

# %%
genres.to_csv('genres.csv')
